# %% [markdown]
# <img src="img/pypesto_logo.png" width="40%" alt="pyPESTO logo"/>
#
# # A Python Package for Parameter Estimation and Uncertainty Quantification
#
#
# This jupyter notebook accompanies my talk at the [COMBINE conference 2020](http://co.mbine.org/events/COMBINE_2020).
#
# [PyPESTO](https://github.com/ICB-DCM/pyPESTO) is a python package for parameter inference. PyPESTO provides an interface to the model simulation tool [AMICI](https://github.com/AMICI-dev/AMICI) and hence is tailored, but not restricted, to Ordinary Differential Equation (ODE) models specified in the [SBML](https://github.com/ICB-DCM/pyPESTO) & [PEtab](https://github.com/PEtab-dev/PEtab) standard.
#
# Mathematically, this talk focus on ODE models of the form
# \begin{align*}
# \dot{x} &= f(x, \theta), \;\;\; x_0=x_0(\theta) \\
# d_i &= h(x(t_i, \theta), \theta) + \varepsilon_i
# \end{align*}
#
# With i.i.d. measurement noise $\varepsilon_i$. Parameter estimates $\hat{\theta}$ are commonly derived via
# maximizing a likelihood or posterior distribution.

# %%
import pypesto
import pypesto.petab 
import pypesto.optimize as optimize
import pypesto.visualize as visualize

import petab
import amici
import os.path
import numpy as np

# %% [markdown]
# # Model Import and Optimization via PEtab
#
# The easiest way to define and import a parameter fitting problem in pyPESTO is by importing a PEtab problem.
#
# ## PEtab
#
# PEtab is a data format for specifying parameter estimation problems in systems biology.
#
# <img src="img/petab_concept.png" width="100%" alt="pyPESTO logo"/>
#
# A PEtab problem consist of an SBML file, defining the model topology and a set of `.tsv` files, defining experimental conditions, observables, measurements and parameters (and their optimization bounds, scale, priors...). All files, that make up a PEtab problem, can get structured in a problem `.yaml` file.
#
# For more details on PEtab, the interested reader is refered to [PEtab's format definition](https://github.com/PEtab-dev/PEtab/blob/master/doc/documentation_data_format.rst), for examples, the reader is refered to the [PEtab benchmark collection](https://github.com/Benchmarking-Initiative/Benchmark-Models-PEtab). The Model by _[Böhm et al. JProteomRes 2014](https://pubs.acs.org/doi/abs/10.1021/pr5006923)_ is part of the benchmark collection and will be used as the running example throughout this notebook.

# %% [markdown]
# ## Basic Model Import and Optimization
#
# The first step is to import a PEtab problem and create a `pypesto.problem` object:

# %%
# %%capture
# directory of the PEtab problem
petab_yaml = './Boehm_JProteomeRes2014/Boehm_JProteomeRes2014.yaml' 

importer = pypesto.petab.PetabImporter.from_yaml(petab_yaml)
problem = importer.create_problem()
# Out:
# 2020-09-30 15:58:25.682 - amici.petab_import - INFO - Importing model ...
# 2020-09-30 15:58:25.684 - amici.petab_import - INFO - Model name is 'Boehm_JProteomeRes2014'.
# Writing model code to '/Users/jvanhoefer/Dokumente/PhD/Talks/Conferences/COMBINE 2020/jupyter notebook/amici_models/Boehm_JProteomeRes2014'.
# 2020-09-30 15:58:25.685 - amici.petab_import - INFO - Species: 8
# 2020-09-30 15:58:25.686 - amici.petab_import - INFO - Global parameters: 9
# 2020-09-30 15:58:25.686 - amici.petab_import - INFO - Reactions: 9
# 2020-09-30 15:58:25.744 - amici.petab_import - INFO - Observables: 3
# 2020-09-30 15:58:25.744 - amici.petab_import - INFO - Sigmas: 3
# 2020-09-30 15:58:25.749 - amici.petab_import - DEBUG - Adding output parameters to model: OrderedDict([('noiseParameter1_pSTAT5A_rel', None), ('noiseParameter1_pSTAT5B_rel', None), ('noiseParameter1_rSTAT5A_rel', None)])
# 2020-09-30 15:58:25.750 - amici.petab_import - DEBUG - Condition table: (1, 1)
# 2020-09-30 15:58:25.751 - amici.petab_import - DEBUG - Fixed parameters are []
# 2020-09-30 15:58:25.751 - amici.petab_import - INFO - Overall fixed parameters: 0
# 2020-09-30 15:58:25.752 - amici.petab_import - INFO - Variable parameters: 12
# 2020-09-30 15:58:25.787 - amici.sbml_import - INFO - Finished processing SBML parameters          + (4.04E-04s)
# 2020-09-30 15:58:25.807 - amici.sbml_import - INFO - Finished processing SBML compartments        + (2.35E-04s)
# 2020-09-30 15:58:25.839 - amici.sbml_import - INFO - Finished processing SBML species             + (1.27E-02s)
# 2020-09-30 15:58:25.881 - amici.sbml_import - INFO - Finished processing SBML reactions           + (2.08E-02s)
# 2020-09-30 15:58:25.905 - amici.sbml_import - INFO - Finished processing SBML rules               + (7.46E-03s)
# 2020-09-30 15:58:25.957 - amici.sbml_import - INFO - Finished processing SBML observables         + (3.21E-02s)
# 2020-09-30 15:58:26.054 - amici.ode_export - INFO - Finished running smart_multiply              ++ (3.31E-03s)
# 2020-09-30 15:58:26.073 - amici.ode_export - INFO - Finished importing SbmlImporter               + (4.68E-02s)
# 2020-09-30 15:58:26.153 - amici.ode_export - INFO - Finished simplifying Jy                    ++++ (1.56E-02s)
# 2020-09-30 15:58:26.154 - amici.ode_export - INFO - Finished computing Jy                       +++ (3.07E-02s)
# 2020-09-30 15:58:26.177 - amici.ode_export - INFO - Finished writing Jy.cpp                      ++ (6.84E-02s)
# 2020-09-30 15:58:26.246 - amici.ode_export - INFO - Finished running smart_jacobian            ++++ (1.98E-02s)
# 2020-09-30 15:58:26.274 - amici.ode_export - INFO - Finished simplifying dJydsigmay            ++++ (9.85E-03s)
# 2020-09-30 15:58:26.274 - amici.ode_export - INFO - Finished computing dJydsigmay               +++ (6.24E-02s)
# 2020-09-30 15:58:26.279 - amici.ode_export - INFO - Finished writing dJydsigmay.cpp              ++ (8.11E-02s)
# 2020-09-30 15:58:26.336 - amici.ode_export - INFO - Finished running smart_jacobian            ++++ (8.63E-03s)
# 2020-09-30 15:58:26.369 - amici.ode_export - INFO - Finished simplifying dJydy                 ++++ (1.17E-02s)
# 2020-09-30 15:58:26.369 - amici.ode_export - INFO - Finished computing dJydy                    +++ (5.63E-02s)
# 2020-09-30 15:58:26.376 - amici.ode_export - INFO - Finished writing dJydy.cpp                   ++ (7.80E-02s)
# 2020-09-30 15:58:26.451 - amici.ode_export - INFO - Finished simplifying w                    +++++ (1.09E-02s)
# 2020-09-30 15:58:26.452 - amici.ode_export - INFO - Finished computing w                       ++++ (2.67E-02s)
# 2020-09-30 15:58:26.497 - amici.ode_export - INFO - Finished running smart_jacobian            ++++ (2.45E-02s)
# 2020-09-30 15:58:26.530 - amici.ode_export - INFO - Finished simplifying dwdp                  ++++ (1.52E-02s)
# 2020-09-30 15:58:26.530 - amici.ode_export - INFO - Finished computing dwdp                     +++ (1.19E-01s)
# 2020-09-30 15:58:26.541 - amici.ode_export - INFO - Finished writing dwdp.cpp                    ++ (1.44E-01s)
# 2020-09-30 15:58:26.608 - amici.ode_export - INFO - Finished running smart_jacobian            ++++ (1.55E-02s)
# 2020-09-30 15:58:26.637 - amici.ode_export - INFO - Finished simplifying dwdx                  ++++ (8.95E-03s)
# 2020-09-30 15:58:26.637 - amici.ode_export - INFO - Finished computing dwdx                     +++ (6.04E-02s)
# 2020-09-30 15:58:26.645 - amici.ode_export - INFO - Finished writing dwdx.cpp                    ++ (8.24E-02s)
# 2020-09-30 15:58:26.694 - amici.ode_export - INFO - Finished running smart_jacobian            ++++ (3.11E-04s)
# 2020-09-30 15:58:26.714 - amici.ode_export - INFO - Finished simplifying dwdw                  ++++ (3.01E-04s)
# 2020-09-30 15:58:26.715 - amici.ode_export - INFO - Finished computing dwdw                     +++ (3.53E-02s)
# 2020-09-30 15:58:26.716 - amici.ode_export - INFO - Finished writing dwdw.cpp                    ++ (5.11E-02s)
# 2020-09-30 15:58:26.773 - amici.ode_export - INFO - Finished simplifying xdot                  ++++ (7.09E-03s)
# 2020-09-30 15:58:26.774 - amici.ode_export - INFO - Finished computing xdot                     +++ (2.20E-02s)
# 2020-09-30 15:58:26.787 - amici.ode_export - INFO - Finished writing dxdotdw.cpp                 ++ (5.16E-02s)
# 2020-09-30 15:58:26.843 - amici.ode_export - INFO - Finished running smart_jacobian            ++++ (1.80E-03s)
# 2020-09-30 15:58:26.864 - amici.ode_export - INFO - Finished simplifying dxdotdx_explicit      ++++ (2.42E-04s)
# 2020-09-30 15:58:26.864 - amici.ode_export - INFO - Finished computing dxdotdx_explicit         +++ (3.90E-02s)
# 2020-09-30 15:58:26.866 - amici.ode_export - INFO - Finished writing dxdotdx_explicit.cpp        ++ (5.80E-02s)
# 2020-09-30 15:58:26.923 - amici.ode_export - INFO - Finished running smart_jacobian            ++++ (3.28E-04s)
# 2020-09-30 15:58:26.943 - amici.ode_export - INFO - Finished simplifying dxdotdp_explicit      ++++ (3.14E-04s)
# 2020-09-30 15:58:26.944 - amici.ode_export - INFO - Finished computing dxdotdp_explicit         +++ (3.83E-02s)
# 2020-09-30 15:58:26.945 - amici.ode_export - INFO - Finished writing dxdotdp_explicit.cpp        ++ (5.94E-02s)
# 2020-09-30 15:58:27.052 - amici.ode_export - INFO - Finished simplifying y                   ++++++ (2.47E-02s)
# 2020-09-30 15:58:27.053 - amici.ode_export - INFO - Finished computing y                      +++++ (3.89E-02s)
# 2020-09-30 15:58:27.113 - amici.ode_export - INFO - Finished running smart_jacobian           +++++ (3.83E-02s)
# 2020-09-30 15:58:27.196 - amici.ode_export - INFO - Finished simplifying dydx                 +++++ (6.47E-02s)
# 2020-09-30 15:58:27.196 - amici.ode_export - INFO - Finished computing dydx                    ++++ (1.97E-01s)
# 2020-09-30 15:58:27.233 - amici.ode_export - INFO - Finished running smart_jacobian           +++++ (1.98E-04s)
# 2020-09-30 15:58:27.250 - amici.ode_export - INFO - Finished simplifying dydw                 +++++ (1.25E-04s)
# 2020-09-30 15:58:27.251 - amici.ode_export - INFO - Finished computing dydw                    ++++ (3.22E-02s)
# 2020-09-30 15:58:27.330 - amici.ode_export - INFO - Finished simplifying dydx                  ++++ (5.91E-02s)
# 2020-09-30 15:58:27.331 - amici.ode_export - INFO - Finished computing dydx                     +++ (3.46E-01s)
# 2020-09-30 15:58:27.356 - amici.ode_export - INFO - Finished writing dydx.cpp                    ++ (3.86E-01s)
# 2020-09-30 15:58:27.466 - amici.ode_export - INFO - Finished running smart_jacobian           +++++ (2.25E-02s)
# 2020-09-30 15:58:27.514 - amici.ode_export - INFO - Finished simplifying dydp                 +++++ (2.55E-02s)
# 2020-09-30 15:58:27.515 - amici.ode_export - INFO - Finished computing dydp                    ++++ (9.50E-02s)
# 2020-09-30 15:58:27.558 - amici.ode_export - INFO - Finished simplifying dydp                  ++++ (2.08E-02s)
# 2020-09-30 15:58:27.559 - amici.ode_export - INFO - Finished computing dydp                     +++ (1.60E-01s)
# 2020-09-30 15:58:27.568 - amici.ode_export - INFO - Finished writing dydp.cpp                    ++ (1.90E-01s)
# 2020-09-30 15:58:27.658 - amici.ode_export - INFO - Finished simplifying sigmay               +++++ (6.35E-05s)
# 2020-09-30 15:58:27.659 - amici.ode_export - INFO - Finished computing sigmay                  ++++ (2.40E-02s)
# 2020-09-30 15:58:27.686 - amici.ode_export - INFO - Finished running smart_jacobian            ++++ (1.72E-03s)
# 2020-09-30 15:58:27.712 - amici.ode_export - INFO - Finished simplifying dsigmaydp             ++++ (1.77E-04s)
# 2020-09-30 15:58:27.713 - amici.ode_export - INFO - Finished computing dsigmaydp                +++ (1.00E-01s)
# 2020-09-30 15:58:27.715 - amici.ode_export - INFO - Finished writing dsigmaydp.cpp               ++ (1.24E-01s)
# 2020-09-30 15:58:27.741 - amici.ode_export - INFO - Finished writing sigmay.cpp                  ++ (1.02E-03s)
# 2020-09-30 15:58:27.772 - amici.ode_export - INFO - Finished writing w.cpp                       ++ (4.67E-03s)
# 2020-09-30 15:58:27.846 - amici.ode_export - INFO - Finished simplifying x0                    ++++ (1.74E-03s)
# 2020-09-30 15:58:27.847 - amici.ode_export - INFO - Finished computing x0                       +++ (2.64E-02s)
# 2020-09-30 15:58:27.849 - amici.ode_export - INFO - Finished writing x0.cpp                      ++ (5.24E-02s)
# 2020-09-30 15:58:27.924 - amici.ode_export - INFO - Finished simplifying x0_fixedParameters    ++++ (4.66E-05s)
# 2020-09-30 15:58:27.925 - amici.ode_export - INFO - Finished computing x0_fixedParameters       +++ (2.55E-02s)
# 2020-09-30 15:58:27.926 - amici.ode_export - INFO - Finished writing x0_fixedParameters.cpp      ++ (4.98E-02s)
# 2020-09-30 15:58:28.005 - amici.ode_export - INFO - Finished running smart_jacobian            ++++ (4.53E-03s)
# 2020-09-30 15:58:28.030 - amici.ode_export - INFO - Finished simplifying sx0                   ++++ (3.99E-04s)
# 2020-09-30 15:58:28.031 - amici.ode_export - INFO - Finished computing sx0                      +++ (5.44E-02s)
# 2020-09-30 15:58:28.033 - amici.ode_export - INFO - Finished writing sx0.cpp                     ++ (8.10E-02s)
# 2020-09-30 15:58:28.107 - amici.ode_export - INFO - Finished running smart_jacobian            ++++ (4.63E-05s)
# 2020-09-30 15:58:28.133 - amici.ode_export - INFO - Finished running smart_jacobian            ++++ (3.99E-05s)
# 2020-09-30 15:58:28.159 - amici.ode_export - INFO - Finished simplifying sx0_fixedParameters   ++++ (4.32E-05s)
# 2020-09-30 15:58:28.159 - amici.ode_export - INFO - Finished computing sx0_fixedParameters      +++ (7.63E-02s)
# 2020-09-30 15:58:28.161 - amici.ode_export - INFO - Finished writing sx0_fixedParameters.cpp     ++ (1.01E-01s)
# 2020-09-30 15:58:28.200 - amici.ode_export - INFO - Finished writing xdot.cpp                    ++ (1.11E-02s)
# 2020-09-30 15:58:28.229 - amici.ode_export - INFO - Finished writing y.cpp                       ++ (3.77E-03s)
# 2020-09-30 15:58:28.298 - amici.ode_export - INFO - Finished simplifying x_rdata               ++++ (8.45E-05s)
# 2020-09-30 15:58:28.299 - amici.ode_export - INFO - Finished computing x_rdata                  +++ (2.46E-02s)
# 2020-09-30 15:58:28.302 - amici.ode_export - INFO - Finished writing x_rdata.cpp                 ++ (5.02E-02s)
# 2020-09-30 15:58:28.366 - amici.ode_export - INFO - Finished simplifying total_cl              ++++ (3.73E-05s)
# 2020-09-30 15:58:28.366 - amici.ode_export - INFO - Finished computing total_cl                 +++ (2.13E-02s)
# 2020-09-30 15:58:28.367 - amici.ode_export - INFO - Finished writing total_cl.cpp                ++ (3.91E-02s)
# 2020-09-30 15:58:28.422 - amici.ode_export - INFO - Finished simplifying x_solver              ++++ (6.33E-05s)
# 2020-09-30 15:58:28.422 - amici.ode_export - INFO - Finished computing x_solver                 +++ (1.48E-02s)
# 2020-09-30 15:58:28.425 - amici.ode_export - INFO - Finished writing x_solver.cpp                ++ (3.56E-02s)
# 2020-09-30 15:58:28.439 - amici.ode_export - INFO - Finished generating cpp code                  + (2.34E+00s)
# 2020-09-30 15:58:45.761 - amici.ode_export - INFO - Finished compiling cpp code                   + (1.73E+01s)
# 2020-09-30 15:58:45.763 - amici.petab_import - INFO - Finished Importing PEtab model                (2.01E+01s)

# %% [markdown]
# Next, we choose an `optimizer` and a number of optimization runs (`n_starts`) to perform the multi start optimization.

# %%
# %%time
# %%capture

optimizer = optimize.ScipyOptimizer()

# do the optimization
result = optimize.minimize(problem=problem, 
                           optimizer=optimizer,
                           n_starts=10)
# Out:
# CPU times: user 15.6 s, sys: 299 ms, total: 15.9 s
# Wall time: 15.9 s

# %% [markdown]
# `result.optimize_result` now stores as list, that contains the results and meta data of the individual optimizer runs (ordered by function value).

# %%
# E.g. best model fit was obtained by the following optimization run:
result.optimize_result.list[0]
# Out:
# {'id': '6',
#  'x': array([-1.56907242, -5.        , -2.2098735 , -1.78589794,  2.98669666,
#          4.19768286,  0.693     ,  0.58565973,  0.81887318,  0.49859149,
#          0.107     ]),
#  'fval': 138.22393388567312,
#  'grad': array([ 0.01072908,  0.05536787,  0.00091059,  0.01577042, -0.0045581 ,
#         -0.01034549,         nan, -0.00218799, -0.00150021, -0.0017974 ,
#                 nan]),
#  'hess': None,
#  'res': None,
#  'sres': None,
#  'n_fval': 148,
#  'n_grad': 148,
#  'n_hess': 0,
#  'n_res': 0,
#  'n_sres': 0,
#  'x0': array([-2.80178748, -2.23836567, -0.89264584, -1.78604393, -2.97957632,
#          2.15370539,  0.693     , -4.94087059, -0.84585338,  4.91992308,
#          0.107     ]),
#  'fval0': 168289876229827.94,
#  'history': <pypesto.objective.history.History at 0x7fedaccafc50>,
#  'exitflag': 0,
#  'time': 4.343586206436157,
#  'message': b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'}

# %%
# Objective function values of the different optimizer runs:
result.optimize_result.get_for_key('fval')
# Out:
# [138.22393388567312,
#  147.55016857541608,
#  151.009391787326,
#  151.0115600482835,
#  235.74061165641342,
#  249.74437900613958,
#  249.74599678184373,
#  249.74599742223873,
#  249.74599744290393,
#  249.74599744338096]

# %% [markdown]
# ## Optimizer Choice
#
# PyPESTO provides a unified interface to a variety of optimizers of different types:
#
# * All [scipy optimizer](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.minimize.html#scipy.optimize.minimize) (`optimize.ScipyOptimizer(method=<method_name>)`)
#     * _function-value_ or _least-squares_-based optimizers
#     * _gradient_ or _hessian_-based optimizers
# * [IpOpt](https://pypi.org/project/ipopt/) (`optimize.IpoptOptimizer()`)
#     * Interior point method
# * [Dlib](http://dlib.net) (`optimize.DlibOptimizer(options={'maxiter': <max. number of iterations>})`)
#     * Globa optimizer
#     * gradient free
# * [Particle Swarm](https://github.com/tisimst/pyswarm) (`optimize.PyswarmOptimizer()`)
#     * Particle swarm algorithm
#     * gradient free
# * [CMA-ES](https://pypi.org/project/cma-es/) (`optimize.CmaesOptimizer()`)
#     * Covariance Matrix Adaptation Evolution Strategy
#     * Evolutionary Algorithm

# %%
optimizer_scipy_lbfgsb = optimize.ScipyOptimizer(method='L-BFGS-B')
optimizer_scipy_powell = optimize.ScipyOptimizer(method='Powell')

optimizer_dlib = optimize.DlibOptimizer(method = '', options={'maxiter': 1000})
optimizer_pyswarm = optimize.PyswarmOptimizer()

# %% [markdown]
# The following performs 100 multi-start runs with different optimizers in order to compare their performance.
#
# _Note_: `dlib` and `pyswarm` need to be installed for this section to run. Furthermore the computation time is in the order of minutes, so you might want to skip the excecution and jump to the next section.

# %%
# %%time
# %%capture
n_starts = 100

# Due to run time we already use parallelization. 
# This will be introduced in more detail later.
engine = pypesto.engine.MultiProcessEngine()
history_options = pypesto.HistoryOptions(trace_record=True)

# Scipy: L-BFGS-B
result_lbfgsb = optimize.minimize(problem=problem, 
                                  optimizer=optimizer_scipy_lbfgsb,
                                  engine=engine,
                                  history_options=history_options,
                                  n_starts=n_starts)

# Scipy: Powell
result_powell = optimize.minimize(problem=problem, 
                              optimizer=optimizer_scipy_powell,
                              engine=engine,
                              history_options=history_options,
                              n_starts=n_starts)

# Dlib
result_dlib = optimize.minimize(problem=problem, 
                                optimizer=optimizer_dlib,
                                engine=engine,
                                history_options=history_options,
                                n_starts=n_starts)


# PySwarm
result_pyswarm = optimize.minimize(problem=problem, 
                                   optimizer=optimizer_pyswarm,
                                   engine=engine,
                                   history_options=history_options,
                                   n_starts=n_starts)
# Out:
# CPU times: user 6.66 s, sys: 1.18 s, total: 7.84 s
# Wall time: 18min 56s

# %% [markdown]
# ## Optimizer Convergence
#
#
#
# # TODO

# %%
optimizer_results = [result_lbfgsb, result_powell, result_dlib, result_pyswarm]
optimizer_names = ['Scipy: L-BFGS-B', 'Scipy: Powell', 'Dlib', 'pyswarm']

pypesto.visualize.waterfall(optimizer_results, legends = optimizer_names)

# %% [markdown]
# ## Optimizer run time
#
# Optimizer run time vastly differs among the different optimizers, as can be seen below:

# %%
print('Run time per start:') 
print('-------------------')

for optimizer_name, optimizer_result in zip(optimizer_names, optimizer_results):
    t = np.sum(optimizer_result.optimize_result.get_for_key('time'))/n_starts
    print(f'{optimizer_name}: {t} s')
# Out:
# Run time per start:
# -------------------
# Scipy: L-BFGS-B: 3.1494835805892945 s
# Scipy: Powell: 23.998364126682283 s
# Dlib: 7.0082378935813905 s
# pyswarm: 37.346793506145474 s

# %% [markdown]
# # Fitting of large scale models
#
# When fitting large scale models (i.e. with >100 parameters and accordingly also more data), two important issues are efficient gradient computation and parallelization.
#
# ## Efficient gradient computation
#
# As seen in the example above and as can be confirmed from own experience: If fast and reliable gradients can be provided, gradients based optimizers are favourable with respect to omptimizer convergence and run time.
#
# It has been shown, that adjoint sensitivity analysis propose a fast and reliable method to compute gradients for large scale models, since their run time is (asymptotically) independent of the number of parameters ([Fröhlich et al. PlosCB 2017](https://journals.plos.org/ploscompbiol/article/file?id=10.1371/journal.pcbi.1005331&type=printable)).
#
# <img src="img/adjoint_sensitivities.png" width="40%" alt="pyPESTO logo"/>
#
# (Figure from Fröhlich et al. PlosCB 2017) Adjoint sensitivities are implemented in AMICI.

# %%
# Set gradient computation method to adjoint
problem.objective.amici_model.setSteadyStateSensitivityMode(amici.SensitivityMethod.adjoint)

# %% [markdown]
# ## Parallelization
#
# Multi-start optimization can easily be parallelized by using `engines`.

# %%
# %%time
# %%capture

# Parallelize
engine = pypesto.engine.MultiProcessEngine()

# Optimize
result = optimize.minimize(problem=problem, 
                           optimizer=optimizer_scipy_lbfgsb,
                           engine=engine,
                           n_starts=100)
# Out:
# CPU times: user 595 ms, sys: 86 ms, total: 681 ms
# Wall time: 45.2 s

# %% [markdown]
# # Uncertainty quantification
#
# PyPESTO focuses on two approaches to assess parameter uncertainties:
#
# * Profile likelihoods
# * Sampling
#
# ## Profile Likelihoods
#
# [Profile likelihoods](https://academic.oup.com/bioinformatics/article/25/15/1923/213246) compute confidence intervals via a [likelihood ratio test](https://en.wikipedia.org/wiki/Likelihood-ratio_test). Profile likelihoods perform a maximum-projection of the likelihood function on the parameter of interest. The likelihood ratio test then gives a cut off criterium via the $\chi^2_1$ distribution.
#
# In pyPESTO, the maximum projection is solved as maximization problem and can be obtained via

# %%
# %%time
# %%capture

import pypesto.profile as profile

result = profile.parameter_profile(problem=problem, 
                                   result=result, 
                                   optimizer=optimizer_scipy_lbfgsb)
# Out:
# CPU times: user 1min 16s, sys: 2.2 s, total: 1min 18s
# Wall time: 1min 18s

# %% [markdown]
# The maximum projections can now be inspected via:

# %%
# adapt x_labels..
x_labels = [f'Log10({name})' for name in problem.x_names]

visualize.profiles(result, x_labels = x_labels, show_bounds=True)
# Out:
# [<matplotlib.axes._subplots.AxesSubplot at 0x7fed76c32860>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fed76ca65f8>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fed76e41080>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fed76e889e8>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fed76ebbf28>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fed781a6ba8>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fed781ecba8>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fed78222e10>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fed7827de80>]

# %% [markdown]
# # TODO: Interpretations, which ones are identifiable, which ones not
#
# Furthermore pyPESTO allows to visualize confidence intervals of the paramters directly via

# %%
ax = pypesto.visualize.profile_cis(result, confidence_level=0.95)
ax.set_xlabel('Log10(Parameter value)')
# Out:
# Text(0.5, 0, 'Log10(Parameter value)')

# %% [markdown]
# ## Sampling
#
# In pyPESTO, sampling from the posterior distribution can be performed as

# %%
import pypesto.sample as sample

n_samples = 10000

sampler = sample.AdaptiveMetropolisSampler()

result = sample.sample(problem, 
                       n_samples=n_samples, 
                       sampler=sampler, 
                       result=result)
# Out:
# 100%|██████████| 10000/10000 [00:17<00:00, 561.75it/s]

# %% [markdown]
# Sampling results are stored in `result.sample_result` and can be accessed e.g. via

# %%
result.sample_result['trace_x']
# Out:
# array([[[-1.56905107, -5.        , -2.20982492, ...,  0.58568874,
#           0.81887075,  0.49858645],
#         [-1.56905107, -5.        , -2.20982492, ...,  0.58568874,
#           0.81887075,  0.49858645],
#         [-1.56905107, -5.        , -2.20982492, ...,  0.58568874,
#           0.81887075,  0.49858645],
#         ...,
#         [-1.59002377, -4.26759821, -2.38623004, ...,  0.68584864,
#           0.86531534,  0.41193591],
#         [-1.59002377, -4.26759821, -2.38623004, ...,  0.68584864,
#           0.86531534,  0.41193591],
#         [-1.54290503, -4.33421734, -2.11887681, ...,  0.71558448,
#           0.84961601,  0.44760321]]])

# %% [markdown]
# ### Samlping Diagnostics
#
# Gewekes test accesses convergence of a sampling run and computes the burn in of a sampling result. The effective sample size indicates the strenght the correlation between different samples.

# %%
sample.geweke_test(result=result)
result.sample_result['burn_in']
# Out:
# 2000

# %%
sample.effective_sample_size(result=result)
result.sample_result['effective_sample_size']
# Out:
# 77.48911336747341

# %% [markdown]
# ### Visualization of Sampling Results

# %%
# scatter plots
ax = visualize.sampling_scatter(result)

# marginals
ax = visualize.sampling_1d_marginals(result)

# %% [markdown]
# ## Sampler Choice:
#
# Similarly to parameter optimization, pyPESTO provides a unified interface to several sampler/sampling toolboxes, as well as own implementations of sampler:
#
# * Adaptive Metropolis:   `sample.AdaptiveMetropolisSampler()`
# * Adaptive parallel tempering:   `sample.ParallelTemperingSampler()`
# * Interface to `pymc3` via `sample.Pymc3Sampler()`

# %% [markdown]
# # Software Development Standards:
#
# PyPESTO is developed with the following standards:
#
# * **Open source**, code on [GitHub](https://github.com/ICB-DCM/pyPESTO).
# * [**Pip installable**](https://pypi.org/project/pypesto/) via: `pip install pypesto`.
# * **Documentation** as [RDT](https://pypesto.readthedocs.io/en/stable/) and [example **jupyter notebooks**](https://github.com/ICB-DCM/pyPESTO/tree/master/doc/example) are available.
# * Has **continous integration** & extensive automated **testing** via travis.
# * **Code reviews** before merging into the develop/master branch.
#
# * Currently **5-10 people are using, extending** and (most importantly) **maintaining** pyPESTO in their "daily business".

# %% [markdown]
# # Outlook
#
# Feature that are currently in active development:
#
# * Extending the number of Optimizer/Sampler (special focus on gradient free optimizers)
# * Model Selection
# * Experimental Design
# * Hierarchical Optimization of scaling/noise parameters
# * Categorial Data
